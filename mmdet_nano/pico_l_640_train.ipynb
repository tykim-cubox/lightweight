# %%
import mmcv
import matplotlib.pyplot as plt

# %%
# Choose to use a config and initialize the detector
config = '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/Picodet_Pytorch/configs/picodet/picodet_l_640_coco.py'
# Load the config
cfg = mmcv.Config.fromfile(config)

# %%
# config 수정하기
from mmdet.apis import set_random_seed

# Dataset
cfg.dataset_type = 'COCODataset'
cfg.data_root = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone'

cfg.data.train.ann_file = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/train.json'
cfg.data.train.img_prefix = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs'
cfg.data.train.classes = ('smartphone',)

cfg.data.val.ann_file = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/val.json'
cfg.data.val.img_prefix = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs'
cfg.data.val.classes = ('smartphone',)

cfg.data.test.ann_file = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/val.json'
cfg.data.test.img_prefix = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs'
cfg.data.test.classes = ('smartphone',)

cfg.data.samples_per_gpu= 16 
# Model
cfg.model.bbox_head.num_classes = 1
cfg.model.train_cfg.assigner.num_classes = 1
cfg.model.backbone.init_cfg.checkpoint='/home/aiteam/tykim/scratch/lightweight/mmdet_nano/checkpoints/ESNet_x1_25_pretrained_mmdet_format.pth'
# finetuning을 하기 때문에 pretraiend pth를 설정
cfg.load_from = '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/checkpoints/picodet_l_640_40.4.pth'

cfg.work_dir = '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/pico_l_640_exp'
cfg.device = 'cuda'


# 일단 single gpu에서 해보고
# cfg.optimizer.lr = 0.1
# cfg.gpu_ids = range(1)
cfg.seed = 0
# cfg.runner.max_epochs = 300
set_random_seed(0, deterministic=False)

cfg.log_config.hooks = [
    dict(type='TextLoggerHook'),
    dict(type='TensorboardLoggerHook')]

# %%
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# optimizer = dict(
#     type='SGD', lr=0.30000000000000004, momentum=0.9, weight_decay=4e-05)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='CosineAnnealing',
#     min_lr=0,
#     warmup='linear',
#     warmup_iters=300,
#     warmup_ratio=0.1)
# runner = dict(type='EpochBasedRunner', max_epochs=300)
# checkpoint_config = dict(interval=10)
# log_config = dict(
#     interval=20,
#     hooks=[dict(type='TextLoggerHook'),
#            dict(type='TensorboardLoggerHook')])
# custom_hooks = [
#     dict(type='NumClassCheckHook'),
#     dict(type='CycleEMAHook', cycle_epoch=40, resume_from=None, priority=49)
# ]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/checkpoints/picodet_l_640_40.4.pth'
# resume_from = None
# workflow = [('train', 1)]
# model = dict(
#     type='PicoDet',
#     backbone=dict(
#         type='ESNet',
#         model_size='l',
#         out_indices=[2, 9, 12],
#         frozen_stages=-1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         act_cfg=dict(type='HSwish'),
#         se_cfg=dict(
#             conv_cfg=None,
#             ratio=4,
#             act_cfg=({
#                 'type': 'ReLU'
#             }, {
#                 'type': 'HSigmoid',
#                 'bias': 3.0,
#                 'divisor': 6.0,
#                 'max_value': 6.0
#             })),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/checkpoints/ESNet_x1_25_pretrained_mmdet_format.pth'
#         )),
#     neck=dict(
#         type='CSPPAN',
#         in_channels=[160, 320, 640],
#         act_cfg=dict(type='HSwish'),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         out_channels=160,
#         num_features=4,
#         expansion=1,
#         num_csp_blocks=1),
#     bbox_head=dict(
#         type='PicoDetHead',
#         num_classes=1,
#         in_channels=160,
#         feat_channels=160,
#         stacked_convs=4,
#         kernel_size=5,
#         share_cls_reg=True,
#         use_depthwise=True,
#         reg_max=7,
#         act_cfg=dict(type='HSwish'),
#         strides=[8, 16, 32, 64],
#         norm_cfg=dict(type='BN', requires_grad=True),
#         use_vfl=True,
#         loss_cls=dict(
#             type='VarifocalLoss',
#             use_sigmoid=True,
#             alpha=0.75,
#             gamma=2.0,
#             iou_weighted=True,
#             loss_weight=1.0),
#         loss_dfl=dict(type='DistributionFocalLoss', loss_weight=0.25),
#         loss_bbox=dict(type='GIoULoss', loss_weight=2.0)),
#     train_cfg=dict(
#         assigner=dict(
#             type='SimOTAAssigner', num_classes=1, use_vfl=True, iou_weight=6),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=1000,
#         min_bbox_size=0,
#         score_thr=0.025,
#         nms=dict(type='nms', iou_threshold=0.6),
#         max_per_img=100))
# data_root = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone'
# dataset_type = 'COCODataset'
# img_scales = [(576, 576), (608, 608), (640, 640), (672, 672), (704, 704)]
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile', to_float32=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='MinIoURandomCrop'),
#     dict(
#         type='Resize',
#         img_scale=[(576, 576), (608, 608), (640, 640), (672, 672), (704, 704)],
#         multiscale_mode='value',
#         keep_ratio=False),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='PhotoMetricDistortion',
#         brightness_delta=32,
#         contrast_range=(0.5, 1.5),
#         saturation_range=(0.5, 1.5),
#         hue_delta=18),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', to_float32=True),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(640, 640),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=False),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=16,
#     workers_per_gpu=4,
#     persistent_workers=True,
#     train=dict(
#         type='CocoDataset',
#         ann_file=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/train.json',
#         img_prefix=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs',
#         pipeline=[
#             dict(type='LoadImageFromFile', to_float32=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='MinIoURandomCrop'),
#             dict(
#                 type='Resize',
#                 img_scale=[(576, 576), (608, 608), (640, 640), (672, 672),
#                            (704, 704)],
#                 multiscale_mode='value',
#                 keep_ratio=False),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='PhotoMetricDistortion',
#                 brightness_delta=32,
#                 contrast_range=(0.5, 1.5),
#                 saturation_range=(0.5, 1.5),
#                 hue_delta=18),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         classes=('smartphone', )),
#     val=dict(
#         type='CocoDataset',
#         ann_file=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/val.json',
#         img_prefix=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs',
#         pipeline=[
#             dict(type='LoadImageFromFile', to_float32=True),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(640, 640),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=False),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('smartphone', )),
#     test=dict(
#         type='CocoDataset',
#         ann_file=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/annos/val.json',
#         img_prefix=
#         '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs',
#         pipeline=[
#             dict(type='LoadImageFromFile', to_float32=True),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(640, 640),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=False),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('smartphone', )))
# evaluation = dict(interval=10, metric='bbox')
# work_dir = '/home/aiteam/tykim/scratch/lightweight/mmdet_nano/pico_l_640_exp'
# device = 'cuda'
# seed = 0

# %%
dump_file = "/home/aiteam/tykim/scratch/lightweight/mmdet_nano/pico_l_640_exp/l_640.py"
cfg.dump(dump_file)

# %%
# Jupyer notebook에서 학습시
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

datasets = [build_dataset(cfg.data.train)]
model = build_detector(cfg.model)
model.CLASSES = datasets[0].CLASSES

import os.path as osp
# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_detector(model, datasets, cfg, distributed=False, validate=True)

# %%
# Jupyter notebook에서 Inference시

model.cfg = cfg
model.eval()
# Out:
# PicoDet(
#   (backbone): ESNet(
#     (conv1): ConvModule(
#       (conv): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): HSwish(
#         (act): ReLU6(inplace=True)
#       )
#     )
#     (max_pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2_1): EnhancedInvertedResidualDS(
#       (conv_dw_1): ConvModule(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv_linear_1): ConvModule(
#         (conv): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_2): ConvModule(
#         (conv): Conv2d(24, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_2): ConvModule(
#         (conv): Conv2d(44, 44, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=44, bias=False)
#         (bn): BatchNorm2d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(44, 11, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(11, 44, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear_2): ConvModule(
#         (conv): Conv2d(44, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_mv1): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_mv1): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (2_2): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (2_3): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_1): EnhancedInvertedResidualDS(
#       (conv_dw_1): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv_linear_1): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_2): ConvModule(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_2): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear_2): ConvModule(
#         (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_mv1): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_mv1): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_2): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(120, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_3): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_4): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(120, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_5): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_6): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (3_7): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (4_1): EnhancedInvertedResidualDS(
#       (conv_dw_1): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv_linear_1): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_2): ConvModule(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_2): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear_2): ConvModule(
#         (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw_mv1): ConvModule(
#         (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_pw_mv1): ConvModule(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (4_2): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#     (4_3): EnhancedInvertedResidual(
#       (conv_pw): ConvModule(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (conv_dw): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): SELayer(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (conv1): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#         (conv2): ConvModule(
#           (conv): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#           (activate): HSigmoid()
#         )
#       )
#       (conv_linear): ConvModule(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'MODEL_DIR/ESNet_x0_75_pretrained_mmdet_format.pth'}
#   (neck): CSPPAN(
#     (trans): Transformation_Module(
#       (trans): ModuleList(
#         (0): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6()
#           )
#         )
#         (1): ConvModule(
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6()
#           )
#         )
#         (2): ConvModule(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6()
#           )
#         )
#       )
#     )
#     (first_top_conv): DepthwiseSeparableConvModule(
#       (depthwise_conv): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (pointwise_conv): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     (second_top_conv): DepthwiseSeparableConvModule(
#       (depthwise_conv): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#       (pointwise_conv): ConvModule(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): HSwish(
#           (act): ReLU6(inplace=True)
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (reduce_layers): ModuleList()
#     (top_down_blocks): ModuleList(
#       (0): CSPLayer(
#         (main_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (short_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (final_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (blocks): Sequential(
#           (0): DarknetBottleneck(
#             (conv1): ConvModule(
#               (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): HSwish(
#                 (act): ReLU6(inplace=True)
#               )
#             )
#             (conv2): DepthwiseSeparableConvModule(
#               (depthwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48, bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#               (pointwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): CSPLayer(
#         (main_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (short_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (final_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (blocks): Sequential(
#           (0): DarknetBottleneck(
#             (conv1): ConvModule(
#               (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): HSwish(
#                 (act): ReLU6(inplace=True)
#               )
#             )
#             (conv2): DepthwiseSeparableConvModule(
#               (depthwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48, bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#               (pointwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (downsamples): ModuleList(
#       (0): DepthwiseSeparableConvModule(
#         (depthwise_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (pointwise_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#       )
#       (1): DepthwiseSeparableConvModule(
#         (depthwise_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (pointwise_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom_up_blocks): ModuleList(
#       (0): CSPLayer(
#         (main_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (short_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (final_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (blocks): Sequential(
#           (0): DarknetBottleneck(
#             (conv1): ConvModule(
#               (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): HSwish(
#                 (act): ReLU6(inplace=True)
#               )
#             )
#             (conv2): DepthwiseSeparableConvModule(
#               (depthwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48, bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#               (pointwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): CSPLayer(
#         (main_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (short_conv): ConvModule(
#           (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (final_conv): ConvModule(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): HSwish(
#             (act): ReLU6(inplace=True)
#           )
#         )
#         (blocks): Sequential(
#           (0): DarknetBottleneck(
#             (conv1): ConvModule(
#               (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): HSwish(
#                 (act): ReLU6(inplace=True)
#               )
#             )
#             (conv2): DepthwiseSeparableConvModule(
#               (depthwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=48, bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#               (pointwise_conv): ConvModule(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): HSwish(
#                   (act): ReLU6(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (bbox_head): PicoDetHead(
#     (loss_cls): VarifocalLoss()
#     (loss_bbox): GIoULoss()
#     (cls_convs): ModuleList(
#       (0): ModuleList(
#         (0): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#         (1): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#       )
#       (1): ModuleList(
#         (0): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#         (1): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#       )
#       (2): ModuleList(
#         (0): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#         (1): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#       )
#       (3): ModuleList(
#         (0): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#         (1): DepthwiseSeparableConvModule(
#           (depthwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#           (pointwise_conv): ConvModule(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): HSwish(
#               (act): ReLU6(inplace=True)
#             )
#           )
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): ModuleList()
#       (1): ModuleList()
#       (2): ModuleList()
#       (3): ModuleList()
#     )
#     (gfl_cls): ModuleList(
#       (0): Conv2d(96, 33, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 33, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 33, kernel_size=(1, 1), stride=(1, 1))
#       (3): Conv2d(96, 33, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (integral): Integral()
#     (loss_dfl): DistributionFocalLoss()
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'gfl_cls', 'std': 0.01, 'bias_prob': 0.01}}
# )

# %%
from mmdet.apis import inference_detector, show_result_pyplot

# Use the detector to do inference
img = '/home/aiteam/tykim/scratch/lightweight/mmcv_phone/hold_smartphone/imgs/a77.jpg'
result = inference_detector(model, img)
# Let's plot the result
show_result_pyplot(model, img, result, score_thr=0.3)
